# %% [markdown]
# # Visuals
#
# Visualisation is often the only way to verify whether a graph is constructed correct.
#
# Here are a couple of charts below that I use for testing.
# Go and have a look at `tests/test_spatial_graph.py` for some examples.
#
# If that's not what you want right now, there are a couple of pretty charts below...

# %%
try:  # Let's try the simple way:
    from graph import Graph
except ImportError:  
    import os  # we're probably in graph-theory/examples
    os.chdir("..")
    from graph import Graph
# Out:
# 'c:\\Data\\github\\graph-theory'

# %%
from graph import Graph
from graph.random import random_xy_graph, xy_distance
from graph.visuals import plot_2d

# %% [markdown]
# ### A plot of the solution for the traveling salesmans problem for a random_graph

# %%
g = random_xy_graph(200, x_max=800, y_max=400)  # a fully connected graph.
dist, tour = g.solve_tsp()

# convert the route to a graph.
g = Graph()

a = tour[0]
for b in tour[1:]:
    g.add_edge(a, b, xy_distance(a, b))
    a = b
# add the link back to start.
b = tour[0]
g.add_edge(a, b, xy_distance(a, b))

# add a red diamond for the starting point.
plt = plot_2d(g)
start = tour[0:1]
xs, ys = [c[0] for c in start], [c[1] for c in start]
plt.plot(xs, ys, 'rD', clip_on=False)
plt.show(block=False)

# %% [markdown]
# ### A plot of a nice 3D spiral.

# %%
from tests.test_spatial_graph import spiral_graph
g = spiral_graph()
plt = g.plot()
plt.show()

# %% [markdown]
# ### A 3D plot of a fishbone diagram in a couple of orientations.

# %%
from tests.test_spatial_graph import fishbone_graph

g = fishbone_graph()
plt = g.plot()
plt.show(block=False)
plt = g.plot(rotation='yxz')
plt.show(block=False)
plt = g.plot(maintain_aspect_ratio=True)
plt.show(block=False)

# %% [markdown]
# More to come...
